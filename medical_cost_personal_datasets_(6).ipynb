# %% [markdown]
# <a href="https://colab.research.google.com/github/Anitasibuea/Medical-cost-personal-datasets/blob/main/medical_cost_personal_datasets_(6).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %%
insurance=pd.read_csv('/content/insurance.csv')

# %%
insurance.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
insurance.shape
# Out:
# (1338, 7)

# %%
insurance.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
insurance['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
le.fit(["southeast", "southwest", "northwest", "northeast"])
LabelEncoder()
# Out:
# LabelEncoder()

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
catColumns = ['sex', 'smoker', 'region']
insurance_dum = pd.get_dummies(insurance, columns = catColumns, drop_first=True)
insurance_dum.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
X = insurance_dum[['age','bmi', 'smoker_yes']]
y = insurance_dum['charges']

# %%
 sklearn.linear_model import LinearRegressionfrom

# %%
linreg = LinearRegression()

# %%
linreg.fit(X,y) #membuat model regresi untuk x dan y
linreg.score(X,y) #skor regresi linear atau Nilai R square
# Out:
# 0.7474771588119513

# %%
linreg.score(X,y)*100
# Out:
# 74.74771588119513

# %%
linreg.coef_
# Out:
# array([  259.54749155,   322.61513282, 23823.68449531])

# %%
linreg.intercept_
# Out:
# -11676.830425187778

# %%
def calc_insurance(age, bmi, smoking):
 y = ((age*linreg.coef_[0]) + (bmi*linreg.coef_[1]) + (smoking*linreg.coef_[2]) - linreg.intercept_)
 return y

# %%
print(calc_insurance(36, 24, 0))
# Out:
# 28763.303308712788

# %% [markdown]
# **Medical Cost Personal Datasets**
#
# Dipublikasikan oleh Pavan Kumar D,2021
#
# Analisis ini didasarkan pada datasets asuransi yang disediakan oleh Kaggle. Dpat ditemukan di https://www.kaggle.com/code/mragpavank/medical-cost-personal-datasets
